# %% [markdown]
# [Speedup inference](https://x.com/mrsiipa/status/1829429481041449339)

# %%
from transformers import CLIPTokenizer
import matplotlib.pyplot as plt
from PIL import Image
from tqdm import tqdm
import model_loader
import pipeline
import torch
import time

# %%
torch.set_float32_matmul_precision('medium')
print(f"Float32 MatMul Precision set to: {torch.get_float32_matmul_precision()}")
# Out:
# Float32 MatMul Precision set to: medium

# %%
DEVICE = "cpu"

ALLOW_MPS = True
ALLOW_CUDA = False

if torch.cuda.is_available() and ALLOW_CUDA:
    DEVICE = "cuda"
elif (torch.backends.mps.is_built()) and ALLOW_MPS:
    DEVICE = "mps"
print(f"Using device: {DEVICE}")
# Out:
# Using device: mps

# %%
tokenizer = CLIPTokenizer("../data/vocab.json", merges_file="../data/merges.txt")
model_file = "../data/v1-5-pruned-emaonly.ckpt"
models = model_loader.preload_models_from_standard_weights(model_file, DEVICE)

# %%
# Convert models to float16 if using MPS
if DEVICE == "mps":
    for name, model in models.items():
        model = model.half()  # Convert model parameters to float16
        model = model.to(memory_format=torch.channels_last)  # Convert to channels_last
        models[name] = model
    print("Converted models to float16 precision and channels_last memory format for MPS.")
else:
    print("Running on CPU with float32 precision.")
# Out:
# Converted models to float16 precision and channels_last memory format for MPS.

# %% [markdown]
# # Params
#
# ## Text to Image

# %%
# prompt = "A painting of a beautiful sunset over a mountain lake, ultra shart, cinematic, 8k resolution kodak gold 200 film look retro vibe"
# prompt = "A forest with a river running through it, ultra sharp, cinematic, 8k resolution, kodak gold 200 film look, retro vibe, scary monster huggy wuggy hiding in the woods"
prompt = "fantasy map dnd mountains grainy kodak gold film look green and blue"
uncond_prompt = "modern satelite cityscape"
do_cfg = True
cfg_scale = 7

# %% [markdown]
# ## Image to Image

# %%
# input_image = None
image_path = "../images/map.png"
input_image = Image.open(image_path)
input_image = input_image.convert('RGB')  # Convert to RGB mode
input_image = input_image.resize((512, 512), Image.Resampling.LANCZOS)  # Resize to 512x512
strength = 0.4

sampler = "ddpm"
num_inference_steps = 40

plt.imshow(input_image); plt.axis('off'); plt.show()

# %% [markdown]
# # Generation

# %%
seed = torch.randint(0, 1000000, (1,)).item()
seed
# Out:
# 641107

# %%
start_time = time.time()
output_image = pipeline.generate(
    prompt=prompt,
    uncond_prompt=uncond_prompt,
    input_image=input_image,
    strength=strength,
    do_cfg=do_cfg,
    cfg_scale=cfg_scale,
    sampler_name=sampler,
    n_inference_steps=num_inference_steps,
    seed=seed,
    models=models,
    device=DEVICE,
    idle_device="cpu",
    tokenizer=tokenizer,
)
end_time = time.time()
print(f"Time taken: {end_time - start_time}")
# Out:
# 100%|██████████| 16/16 [00:09<00:00,  1.69it/s]
# Time taken: 11.87434196472168

# %%
# Combine the input image and the output image into a single image.
Image.fromarray(output_image)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
plt.figure(figsize=(20, 8))

strengths = [0.2, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.7, 0.8, 0.9, 1.0]
for i, strength in enumerate(tqdm(strengths, desc="Testing strengths")):
    output_image = pipeline.generate(
        prompt=prompt,
        uncond_prompt=uncond_prompt,
        input_image=input_image,
        strength=strength,
        do_cfg=do_cfg,
        cfg_scale=cfg_scale,
        sampler_name=sampler,
        n_inference_steps=num_inference_steps,
        seed=seed,
        models=models,
        device=DEVICE,
        idle_device="cpu",
        tokenizer=tokenizer,
    )

    plt.subplot(2, 6, i+1)
    plt.imshow(output_image)
    plt.title(f"Strength: {strength}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Testing strengths:   0%|          | 0/12 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#  12%|█▎        | 1/8 [00:00<00:03,  1.81it/s]
#  25%|██▌       | 2/8 [00:01<00:03,  1.82it/s]
#  38%|███▊      | 3/8 [00:01<00:02,  1.77it/s]
#  50%|█████     | 4/8 [00:02<00:02,  1.77it/s]
#  62%|██████▎   | 5/8 [00:02<00:01,  1.79it/s]
#  75%|███████▌  | 6/8 [00:03<00:01,  1.78it/s]
#  88%|████████▊ | 7/8 [00:03<00:00,  1.77it/s]
# 100%|██████████| 8/8 [00:04<00:00,  1.78it/s]
# Testing strengths:   8%|▊         | 1/12 [00:14<02:38, 14.40s/it]
#   0%|          | 0/12 [00:00<?, ?it/s]
#   8%|▊         | 1/12 [00:00<00:07,  1.56it/s]
#  17%|█▋        | 2/12 [00:01<00:05,  1.68it/s]
#  25%|██▌       | 3/12 [00:01<00:05,  1.72it/s]
#  33%|███▎      | 4/12 [00:02<00:04,  1.75it/s]
#  42%|████▏     | 5/12 [00:02<00:04,  1.74it/s]
#  50%|█████     | 6/12 [00:03<00:03,  1.76it/s]
#  58%|█████▊    | 7/12 [00:04<00:02,  1.75it/s]
#  67%|██████▋   | 8/12 [00:04<00:02,  1.76it/s]
#  75%|███████▌  | 9/12 [00:05<00:01,  1.77it/s]
#  83%|████████▎ | 10/12 [00:05<00:01,  1.77it/s]
#  92%|█████████▏| 11/12 [00:06<00:00,  1.77it/s]
# 100%|██████████| 12/12 [00:06<00:00,  1.76it/s]
# Testing strengths:  17%|█▋        | 2/12 [00:33<02:49, 16.91s/it]
#   0%|          | 0/14 [00:00<?, ?it/s]
#   7%|▋         | 1/14 [00:00<00:07,  1.80it/s]
#  14%|█▍        | 2/14 [00:01<00:06,  1.79it/s]
#  21%|██▏       | 3/14 [00:01<00:06,  1.79it/s]
#  29%|██▊       | 4/14 [00:02<00:05,  1.79it/s]
#  36%|███▌      | 5/14 [00:02<00:04,  1.80it/s]
#  43%|████▎     | 6/14 [00:03<00:04,  1.79it/s]
#  50%|█████     | 7/14 [00:03<00:03,  1.79it/s]
#  57%|█████▋    | 8/14 [00:04<00:03,  1.78it/s]
#  64%|██████▍   | 9/14 [00:05<00:02,  1.79it/s]
#  71%|███████▏  | 10/14 [00:05<00:02,  1.78it/s]
#  79%|███████▊  | 11/14 [00:06<00:01,  1.78it/s]
#  86%|████████▌ | 12/14 [00:06<00:01,  1.78it/s]
#  93%|█████████▎| 13/14 [00:07<00:00,  1.78it/s]
# 100%|██████████| 14/14 [00:07<00:00,  1.79it/s]
# Testing strengths:  25%|██▌       | 3/12 [00:51<02:38, 17.67s/it]
#   0%|          | 0/16 [00:00<?, ?it/s]
#   6%|▋         | 1/16 [00:00<00:08,  1.76it/s]
#  12%|█▎        | 2/16 [00:01<00:07,  1.79it/s]
#  19%|█▉        | 3/16 [00:01<00:07,  1.79it/s]
#  25%|██▌       | 4/16 [00:02<00:06,  1.79it/s]
#  31%|███▏      | 5/16 [00:02<00:06,  1.79it/s]
#  38%|███▊      | 6/16 [00:03<00:05,  1.78it/s]
#  44%|████▍     | 7/16 [00:03<00:05,  1.79it/s]
#  50%|█████     | 8/16 [00:04<00:04,  1.78it/s]
#  56%|█████▋    | 9/16 [00:05<00:03,  1.79it/s]
#  62%|██████▎   | 10/16 [00:05<00:03,  1.78it/s]
#  69%|██████▉   | 11/16 [00:06<00:02,  1.78it/s]
#  75%|███████▌  | 12/16 [00:06<00:02,  1.78it/s]
#  81%|████████▏ | 13/16 [00:07<00:01,  1.80it/s]
#  88%|████████▊ | 14/16 [00:07<00:01,  1.79it/s]
#  94%|█████████▍| 15/16 [00:08<00:00,  1.79it/s]
# 100%|██████████| 16/16 [00:08<00:00,  1.78it/s]
# Testing strengths:  33%|███▎      | 4/12 [01:11<02:29, 18.65s/it]
#   0%|          | 0/18 [00:00<?, ?it/s]
#   6%|▌         | 1/18 [00:01<00:18,  1.07s/it]
#  11%|█         | 2/18 [00:01<00:12,  1.30it/s]
#  17%|█▋        | 3/18 [00:02<00:10,  1.48it/s]
#  22%|██▏       | 4/18 [00:02<00:08,  1.59it/s]
#  28%|██▊       | 5/18 [00:03<00:07,  1.66it/s]
#  33%|███▎      | 6/18 [00:03<00:07,  1.68it/s]
#  39%|███▉      | 7/18 [00:04<00:06,  1.72it/s]
#  44%|████▍     | 8/18 [00:04<00:05,  1.74it/s]
#  50%|█████     | 9/18 [00:05<00:05,  1.74it/s]
#  56%|█████▌    | 10/18 [00:06<00:04,  1.75it/s]
#  61%|██████    | 11/18 [00:06<00:03,  1.75it/s]
#  67%|██████▋   | 12/18 [00:07<00:03,  1.77it/s]
#  72%|███████▏  | 13/18 [00:07<00:02,  1.77it/s]
#  78%|███████▊  | 14/18 [00:08<00:02,  1.77it/s]
#  83%|████████▎ | 15/18 [00:08<00:01,  1.79it/s]
#  89%|████████▉ | 16/18 [00:09<00:01,  1.79it/s]
#  94%|█████████▍| 17/18 [00:10<00:00,  1.79it/s]
# 100%|██████████| 18/18 [00:10<00:00,  1.70it/s]
# Testing strengths:  42%|████▏     | 5/12 [01:34<02:19, 19.96s/it]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [00:00<00:10,  1.82it/s]
#  10%|█         | 2/20 [00:01<00:09,  1.82it/s]
#  15%|█▌        | 3/20 [00:01<00:09,  1.77it/s]
#  20%|██        | 4/20 [00:02<00:09,  1.78it/s]
#  25%|██▌       | 5/20 [00:02<00:08,  1.77it/s]
#  30%|███       | 6/20 [00:03<00:07,  1.78it/s]
#  35%|███▌      | 7/20 [00:03<00:07,  1.78it/s]
#  40%|████      | 8/20 [00:04<00:06,  1.77it/s]
#  45%|████▌     | 9/20 [00:05<00:06,  1.79it/s]
#  50%|█████     | 10/20 [00:05<00:05,  1.79it/s]
#  55%|█████▌    | 11/20 [00:06<00:05,  1.78it/s]
#  60%|██████    | 12/20 [00:06<00:04,  1.78it/s]
#  65%|██████▌   | 13/20 [00:07<00:03,  1.78it/s]
#  70%|███████   | 14/20 [00:07<00:03,  1.80it/s]
#  75%|███████▌  | 15/20 [00:08<00:02,  1.77it/s]
#  80%|████████  | 16/20 [00:08<00:02,  1.77it/s]
#  85%|████████▌ | 17/20 [00:09<00:01,  1.78it/s]
#  90%|█████████ | 18/20 [00:10<00:01,  1.79it/s]
#  95%|█████████▌| 19/20 [00:10<00:00,  1.77it/s]
# 100%|██████████| 20/20 [00:11<00:00,  1.78it/s]
# Testing strengths:  50%|█████     | 6/12 [01:55<02:03, 20.61s/it]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   5%|▍         | 1/22 [00:00<00:11,  1.82it/s]
#   9%|▉         | 2/22 [00:01<00:11,  1.79it/s]
#  14%|█▎        | 3/22 [00:01<00:10,  1.79it/s]
#  18%|█▊        | 4/22 [00:02<00:10,  1.79it/s]
#  23%|██▎       | 5/22 [00:02<00:09,  1.78it/s]
#  27%|██▋       | 6/22 [00:03<00:08,  1.78it/s]
#  32%|███▏      | 7/22 [00:03<00:08,  1.78it/s]
#  36%|███▋      | 8/22 [00:04<00:07,  1.77it/s]
#  41%|████      | 9/22 [00:05<00:07,  1.77it/s]
#  45%|████▌     | 10/22 [00:05<00:06,  1.76it/s]
#  50%|█████     | 11/22 [00:06<00:06,  1.78it/s]
#  55%|█████▍    | 12/22 [00:06<00:05,  1.79it/s]
#  59%|█████▉    | 13/22 [00:07<00:05,  1.78it/s]
#  64%|██████▎   | 14/22 [00:07<00:04,  1.78it/s]
#  68%|██████▊   | 15/22 [00:08<00:03,  1.79it/s]
#  73%|███████▎  | 16/22 [00:08<00:03,  1.78it/s]
#  77%|███████▋  | 17/22 [00:09<00:02,  1.78it/s]
#  82%|████████▏ | 18/22 [00:10<00:02,  1.79it/s]
#  86%|████████▋ | 19/22 [00:10<00:01,  1.78it/s]
#  91%|█████████ | 20/22 [00:11<00:01,  1.77it/s]
#  95%|█████████▌| 21/22 [00:11<00:00,  1.77it/s]
# 100%|██████████| 22/22 [00:12<00:00,  1.78it/s]
# Testing strengths:  58%|█████▊    | 7/12 [02:20<01:49, 21.89s/it]
#   0%|          | 0/24 [00:00<?, ?it/s]
#   4%|▍         | 1/24 [00:00<00:13,  1.67it/s]
#   8%|▊         | 2/24 [00:01<00:12,  1.73it/s]
#  12%|█▎        | 3/24 [00:01<00:11,  1.75it/s]
#  17%|█▋        | 4/24 [00:02<00:11,  1.76it/s]
#  21%|██        | 5/24 [00:02<00:10,  1.75it/s]
#  25%|██▌       | 6/24 [00:03<00:10,  1.76it/s]
#  29%|██▉       | 7/24 [00:03<00:09,  1.78it/s]
#  33%|███▎      | 8/24 [00:04<00:08,  1.79it/s]
#  38%|███▊      | 9/24 [00:05<00:08,  1.77it/s]
#  42%|████▏     | 10/24 [00:05<00:07,  1.78it/s]
#  46%|████▌     | 11/24 [00:06<00:07,  1.79it/s]
#  50%|█████     | 12/24 [00:06<00:06,  1.79it/s]
#  54%|█████▍    | 13/24 [00:07<00:06,  1.79it/s]
#  58%|█████▊    | 14/24 [00:07<00:05,  1.79it/s]
#  62%|██████▎   | 15/24 [00:08<00:05,  1.79it/s]
#  67%|██████▋   | 16/24 [00:08<00:04,  1.80it/s]
#  71%|███████   | 17/24 [00:09<00:03,  1.78it/s]
#  75%|███████▌  | 18/24 [00:10<00:03,  1.79it/s]
#  79%|███████▉  | 19/24 [00:10<00:02,  1.78it/s]
#  83%|████████▎ | 20/24 [00:11<00:02,  1.77it/s]
#  88%|████████▊ | 21/24 [00:11<00:01,  1.77it/s]
#  92%|█████████▏| 22/24 [00:12<00:01,  1.77it/s]
#  96%|█████████▌| 23/24 [00:12<00:00,  1.77it/s]
# 100%|██████████| 24/24 [00:13<00:00,  1.77it/s]
# Testing strengths:  67%|██████▋   | 8/12 [02:45<01:32, 23.01s/it]
#   0%|          | 0/28 [00:00<?, ?it/s]
#   4%|▎         | 1/28 [00:02<01:01,  2.27s/it]
#   7%|▋         | 2/28 [00:02<00:32,  1.27s/it]
#  11%|█         | 3/28 [00:03<00:24,  1.03it/s]
#  14%|█▍        | 4/28 [00:04<00:19,  1.22it/s]
#  18%|█▊        | 5/28 [00:04<00:16,  1.37it/s]
#  21%|██▏       | 6/28 [00:05<00:14,  1.48it/s]
#  25%|██▌       | 7/28 [00:05<00:13,  1.55it/s]
#  29%|██▊       | 8/28 [00:06<00:12,  1.62it/s]
#  32%|███▏      | 9/28 [00:06<00:11,  1.67it/s]
#  36%|███▌      | 10/28 [00:07<00:10,  1.70it/s]
#  39%|███▉      | 11/28 [00:08<00:09,  1.71it/s]
#  43%|████▎     | 12/28 [00:08<00:09,  1.73it/s]
#  46%|████▋     | 13/28 [00:09<00:08,  1.74it/s]
#  50%|█████     | 14/28 [00:09<00:08,  1.75it/s]
#  54%|█████▎    | 15/28 [00:10<00:07,  1.75it/s]
#  57%|█████▋    | 16/28 [00:10<00:06,  1.74it/s]
#  61%|██████    | 17/28 [00:11<00:06,  1.76it/s]
#  64%|██████▍   | 18/28 [00:11<00:05,  1.76it/s]
#  68%|██████▊   | 19/28 [00:12<00:05,  1.76it/s]
#  71%|███████▏  | 20/28 [00:13<00:04,  1.76it/s]
#  75%|███████▌  | 21/28 [00:13<00:03,  1.75it/s]
#  79%|███████▊  | 22/28 [00:14<00:03,  1.76it/s]
#  82%|████████▏ | 23/28 [00:14<00:02,  1.76it/s]
#  86%|████████▌ | 24/28 [00:15<00:02,  1.77it/s]
#  89%|████████▉ | 25/28 [00:15<00:01,  1.76it/s]
#  93%|█████████▎| 26/28 [00:16<00:01,  1.76it/s]
#  96%|█████████▋| 27/28 [00:17<00:00,  1.77it/s]
# 100%|██████████| 28/28 [00:17<00:00,  1.59it/s]
# Testing strengths:  75%|███████▌  | 9/12 [03:19<01:18, 26.30s/it]
#   0%|          | 0/32 [00:00<?, ?it/s]
#   3%|▎         | 1/32 [00:04<02:30,  4.85s/it]
#   6%|▋         | 2/32 [00:05<01:09,  2.33s/it]
#   9%|▉         | 3/32 [00:05<00:44,  1.52s/it]
#  12%|█▎        | 4/32 [00:06<00:31,  1.14s/it]
#  16%|█▌        | 5/32 [00:07<00:25,  1.07it/s]
#  19%|█▉        | 6/32 [00:07<00:21,  1.24it/s]
#  22%|██▏       | 7/32 [00:08<00:18,  1.37it/s]
#  25%|██▌       | 8/32 [00:08<00:16,  1.48it/s]
#  28%|██▊       | 9/32 [00:09<00:14,  1.57it/s]
#  31%|███▏      | 10/32 [00:09<00:13,  1.62it/s]
#  34%|███▍      | 11/32 [00:10<00:12,  1.67it/s]
#  38%|███▊      | 12/32 [00:11<00:11,  1.69it/s]
#  41%|████      | 13/32 [00:11<00:10,  1.73it/s]
#  44%|████▍     | 14/32 [00:12<00:10,  1.75it/s]
#  47%|████▋     | 15/32 [00:12<00:09,  1.76it/s]
#  50%|█████     | 16/32 [00:13<00:09,  1.76it/s]
#  53%|█████▎    | 17/32 [00:13<00:08,  1.77it/s]
#  56%|█████▋    | 18/32 [00:14<00:07,  1.77it/s]
#  59%|█████▉    | 19/32 [00:14<00:07,  1.78it/s]
#  62%|██████▎   | 20/32 [00:15<00:06,  1.78it/s]
#  66%|██████▌   | 21/32 [00:16<00:06,  1.77it/s]
#  69%|██████▉   | 22/32 [00:16<00:05,  1.78it/s]
#  72%|███████▏  | 23/32 [00:17<00:05,  1.78it/s]
#  75%|███████▌  | 24/32 [00:17<00:04,  1.78it/s]
#  78%|███████▊  | 25/32 [00:18<00:03,  1.78it/s]
#  81%|████████▏ | 26/32 [00:18<00:03,  1.78it/s]
#  84%|████████▍ | 27/32 [00:19<00:02,  1.77it/s]
#  88%|████████▊ | 28/32 [00:20<00:02,  1.78it/s]
#  91%|█████████ | 29/32 [00:20<00:01,  1.77it/s]
#  94%|█████████▍| 30/32 [00:21<00:01,  1.78it/s]
#  97%|█████████▋| 31/32 [00:21<00:00,  1.79it/s]
# 100%|██████████| 32/32 [00:22<00:00,  1.44it/s]
# Testing strengths:  83%|████████▎ | 10/12 [03:55<00:58, 29.45s/it]
#   0%|          | 0/36 [00:00<?, ?it/s]
#   3%|▎         | 1/36 [00:00<00:28,  1.23it/s]
#   6%|▌         | 2/36 [00:01<00:22,  1.50it/s]
#   8%|▊         | 3/36 [00:01<00:20,  1.63it/s]
#  11%|█         | 4/36 [00:02<00:18,  1.69it/s]
#  14%|█▍        | 5/36 [00:03<00:18,  1.71it/s]
#  17%|█▋        | 6/36 [00:03<00:17,  1.72it/s]
#  19%|█▉        | 7/36 [00:04<00:16,  1.75it/s]
#  22%|██▏       | 8/36 [00:04<00:15,  1.75it/s]
#  25%|██▌       | 9/36 [00:05<00:15,  1.75it/s]
#  28%|██▊       | 10/36 [00:05<00:14,  1.76it/s]
#  31%|███       | 11/36 [00:06<00:14,  1.77it/s]
#  33%|███▎      | 12/36 [00:07<00:13,  1.78it/s]
#  36%|███▌      | 13/36 [00:07<00:12,  1.78it/s]
#  39%|███▉      | 14/36 [00:08<00:12,  1.77it/s]
#  42%|████▏     | 15/36 [00:08<00:11,  1.78it/s]
#  44%|████▍     | 16/36 [00:09<00:11,  1.77it/s]
#  47%|████▋     | 17/36 [00:09<00:10,  1.77it/s]
#  50%|█████     | 18/36 [00:10<00:10,  1.77it/s]
#  53%|█████▎    | 19/36 [00:10<00:09,  1.77it/s]
#  56%|█████▌    | 20/36 [00:11<00:09,  1.77it/s]
#  58%|█████▊    | 21/36 [00:12<00:08,  1.78it/s]
#  61%|██████    | 22/36 [00:12<00:07,  1.78it/s]
#  64%|██████▍   | 23/36 [00:13<00:08,  1.52it/s]
#  67%|██████▋   | 24/36 [00:14<00:07,  1.58it/s]
#  69%|██████▉   | 25/36 [00:14<00:06,  1.62it/s]
#  72%|███████▏  | 26/36 [00:15<00:06,  1.67it/s]
#  75%|███████▌  | 27/36 [00:15<00:05,  1.69it/s]
#  78%|███████▊  | 28/36 [00:16<00:04,  1.64it/s]
#  81%|████████  | 29/36 [00:17<00:04,  1.66it/s]
#  83%|████████▎ | 30/36 [00:17<00:03,  1.67it/s]
#  86%|████████▌ | 31/36 [00:18<00:02,  1.67it/s]
#  89%|████████▉ | 32/36 [00:18<00:02,  1.69it/s]
#  92%|█████████▏| 33/36 [00:19<00:01,  1.71it/s]
#  94%|█████████▍| 34/36 [00:19<00:01,  1.73it/s]
#  97%|█████████▋| 35/36 [00:20<00:00,  1.73it/s]
# 100%|██████████| 36/36 [00:21<00:00,  1.71it/s]
# Testing strengths:  92%|█████████▏| 11/12 [04:32<00:31, 31.73s/it]
#   0%|          | 0/40 [00:00<?, ?it/s]
#   2%|▎         | 1/40 [00:04<03:13,  4.95s/it]
#   5%|▌         | 2/40 [00:05<01:33,  2.46s/it]
#   8%|▊         | 3/40 [00:06<00:58,  1.59s/it]
#  10%|█         | 4/40 [00:06<00:43,  1.22s/it]
#  12%|█▎        | 5/40 [00:07<00:34,  1.02it/s]
#  15%|█▌        | 6/40 [00:07<00:28,  1.19it/s]
#  18%|█▊        | 7/40 [00:08<00:24,  1.33it/s]
#  20%|██        | 8/40 [00:09<00:22,  1.45it/s]
#  22%|██▎       | 9/40 [00:09<00:20,  1.54it/s]
#  25%|██▌       | 10/40 [00:10<00:18,  1.60it/s]
#  28%|██▊       | 11/40 [00:10<00:17,  1.66it/s]
#  30%|███       | 12/40 [00:11<00:16,  1.69it/s]
#  32%|███▎      | 13/40 [00:11<00:15,  1.71it/s]
#  35%|███▌      | 14/40 [00:12<00:15,  1.73it/s]
#  38%|███▊      | 15/40 [00:13<00:14,  1.74it/s]
#  40%|████      | 16/40 [00:13<00:13,  1.75it/s]
#  42%|████▎     | 17/40 [00:14<00:13,  1.76it/s]
#  45%|████▌     | 18/40 [00:14<00:12,  1.75it/s]
#  48%|████▊     | 19/40 [00:15<00:11,  1.77it/s]
#  50%|█████     | 20/40 [00:15<00:11,  1.77it/s]
#  52%|█████▎    | 21/40 [00:16<00:10,  1.77it/s]
#  55%|█████▌    | 22/40 [00:17<00:10,  1.77it/s]
#  57%|█████▊    | 23/40 [00:17<00:09,  1.78it/s]
#  60%|██████    | 24/40 [00:18<00:09,  1.77it/s]
#  62%|██████▎   | 25/40 [00:18<00:08,  1.78it/s]
#  65%|██████▌   | 26/40 [00:19<00:07,  1.78it/s]
#  68%|██████▊   | 27/40 [00:19<00:07,  1.78it/s]
#  70%|███████   | 28/40 [00:20<00:06,  1.78it/s]
#  72%|███████▎  | 29/40 [00:20<00:06,  1.78it/s]
#  75%|███████▌  | 30/40 [00:21<00:05,  1.78it/s]
#  78%|███████▊  | 31/40 [00:22<00:05,  1.79it/s]
#  80%|████████  | 32/40 [00:22<00:04,  1.79it/s]
#  82%|████████▎ | 33/40 [00:23<00:03,  1.79it/s]
#  85%|████████▌ | 34/40 [00:23<00:03,  1.79it/s]
#  88%|████████▊ | 35/40 [00:24<00:02,  1.80it/s]
#  90%|█████████ | 36/40 [00:24<00:02,  1.78it/s]
#  92%|█████████▎| 37/40 [00:25<00:01,  1.77it/s]
#  95%|█████████▌| 38/40 [00:26<00:01,  1.77it/s]
#  98%|█████████▊| 39/40 [00:26<00:00,  1.78it/s]
# 100%|██████████| 40/40 [00:27<00:00,  1.47it/s]
# Testing strengths: 100%|██████████| 12/12 [05:16<00:00, 26.35s/it]
